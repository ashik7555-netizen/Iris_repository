# %% [markdown]
# <a href="https://colab.research.google.com/github/ashik7555-netizen/Iris_repository/blob/main/Machine_Learning_%26_Feature_Engineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1. Feature Engineering & Data Preprocessing

# %% [markdown]
# 1.there is a question mark (?). That is the missing value.
#
# 2.145 kg (Patient P103) is significantly higher than 72 kg and 69 kg. It stands far apart from the rest of the group, making it an outlier.
#
#
# 3.dataset is very small....we can fill the missing weight using the mean.
#
# 4.BMI

# %% [markdown]
# Q2. Encoding, Scaling & Correlation

# %% [markdown]
# 1.Movie Genre,
#
# Machine learning models only understand numbers
#
# 2.Budget and Duration.
#
# 3.A correlation of -0.10 is very close to 0. It indicates a very weak negative relationship.
#
# 4.No,Target variables in regression like ratings from 1 to 10 are usually left in their original units so predictions remain easy to interpret.

# %% [markdown]
# Q3. Regression Models & Evaluation Metrics

# %% [markdown]
# 1.Random Forest Regression,It has the lowest Mean Absolute Error
#
# 2.measures the average error directly in the actual currency/unit of sales
#
# 3.Classification accuracy is meant for predicting categories
#
# 4.RMSE

# %% [markdown]
# Q4. Classification Algorithms

# %% [markdown]
# 1.Logistic Regression
#
# Logistic Regression provides straightforward probability outputs and feature importance
#
# 2..Logistic Regression
#
# 3.KNN

# %% [markdown]
# Q5. Decision Trees, Random Forest & Cross Validation

# %% [markdown]
# 1.Overfitting.
#
# 2.The Decision Tree memorized the training data perfectly but it failed to generalize to new, unseen testing data. It grew too deep and noise was learned as rules.
#
# 3.Random Forest builds multiple decision trees on random subsets of data and averages their votes. This reduces variance and prevents the model from relying on a single overfitted tree.
#
# 4.It tests the model on multiple different splits of the data to ensure performance estimates are consistent and reliable, rather than just lucky on one test set.

# %% [markdown]
# Q6. Feature Reduction & PCA

# %% [markdown]
# 1.PCA excels at combining redundant variables into a small set of uncorrelated components while preserving maximum information.
#
# 2.Eliminates multicollinearity,
# reduces computation time and memory usage.
#
# 3.Loss of interpretability
#
# 4.Prevents the "curse of dimensionality," speeds up training time, and lowers the risk of overfitting.

# %% [markdown]
# Q7. Ensemble Learning

# %% [markdown]
# 1.Ensemble Learning.
#
# 2.Bagging reduces variance.
#
# Boosting: reduces bias.
#
# 3.Random Forest.
#
# 4.XGBoost
